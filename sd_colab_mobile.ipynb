# %% [markdown]
# <center>
#
# ---
#
# <font size="6"> <b>Stable Diffusion<br>Mobile Version</b></font>
#
# ---
# </center>
#
# ><font color="#33d6ff"><b>README.md</b></font>
#
# <font size="2"><i>Project ini dibuat menggunakan kumpulan repository berbagai macam sumber dari pengguna GitHub, sewaktu-waktu error bisa saja terjadi diluar kendali saya (21sysai).</i></font>
#
# <center>
#
# ---
#
# <p align="left"> <font ><b>Connect with me</b> :</font>
# <a href="https://instagram.com/bagaseka_apr" target="blank"><img align="center" src="https://raw.githubusercontent.com/rahuldkjain/github-profile-readme-generator/master/src/images/icons/Social/instagram.svg" alt="bagaseka_apr" height="30" width="40" /></a>
# <a href="https://fb.com/bagasekaaprs" target="blank"><img align="center" src="https://raw.githubusercontent.com/rahuldkjain/github-profile-readme-generator/master/src/images/icons/Social/facebook.svg" alt="noe999x" height="30" width="40" /></a>
# <a href="https://pinterest.com/21sysai/" target="blank"><img align="center" src="https://upload.wikimedia.org/wikipedia/commons/0/08/Pinterest-logo.png" alt="21sysai" height="30" width="30" /></a>
# <a href="https://pixiv.net/en/users/86925784" target="blank"><img align="center" src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Pixiv_Icon.svg/1200px-Pixiv_Icon.svg.png" alt="21sysai" height="30" width="30" /></a>
# <a href="https://github.com/noe999x" target="blank"><img align="center" src="https://cdn-icons-png.flaticon.com/512/25/25231.png" alt="noe999x" height="30" width="30" /></a></p>
#
# ---
#
# <p align="left"><font><b>Support me</b> :</font></p>
#
# <a href="https://www.buymeacoffee.com/21sysai"> <img align="center" src="https://cdn.buymeacoffee.com/buttons/v2/default-yellow.png" height="50" width="210" alt="21sysai" /></a><a href="https://trakteer.id/21sysai/tip"> <img align="center" src="https://trakteer.id/images/mix/navbar-logo-lite.png" height="50" width="210" alt="21sysai" /></a>
#
# ---
#
# <font size="2"> <i>@21sysai (beta version)</i> </font>
#
# ---
# <br><br><br><br>

# %% [markdown]
# ><font size="3">Jalankan Cell dan install secara bertahap.</font>

# %%
#@markdown # Install Extensions

#module
import base64
import os
import urllib.request
from time import sleep
from IPython.display import clear_output

### -warna-font
H = '\033[1;32m'
D = '\033[0m'
B = '\033[1;34m'
M = '\033[1;31m'

###-decode_base64
sysai = base64.b64decode(("d2VidWk=").encode('ascii')).decode('ascii')
print(f"{H}Menginstall extensions!...{D}")

###-import extensions & webui
#!curl -Lo AUTOMATIC1111-mobile.rar https://huggingface.co/21sysai/AUTOMATIC1111-mobile/resolve/main/AUTOMATIC1111-mobile.zip
#!unzip /content/AUTOMATIC1111-mobile.rar
# !git clone https://github.com/21sysai/AUTOMATIC1111-mobile
# !git clone https://github.com/Bing-su/sd-$sysai-tunnels /content/AUTOMATIC1111-mobile/extensions/sd-tunnels
# !git clone https://github.com/noe999x/sd-$sysai-controlnet /content/AUTOMATIC1111-mobile/extensions/sd-controlnet
# !git clone https://github.com/fkunn1326/openpose-editor /content/AUTOMATIC1111-mobile/extensions/openpose-editor
# !git clone https://github.com/hnmr293/posex /content/AUTOMATIC1111-mobile/extensions/posex
# !git clone https://github.com/DominikDoom/a1111-sd-$sysai-tagcomplete /content/AUTOMATIC1111-mobile/extensions/sd-tagcomplete
# !git clone https://github.com/hako-mikan/sd-$sysai-supermerger /content/AUTOMATIC1111-mobile/extensions/sd-supermerger
# !git clone https://github.com/Coyote-A/ultimate-upscale-for-automatic1111 /content/AUTOMATIC1111-mobile/extensions/ultimate-upscale-for-automatic1111
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-$sysai-locon /content/AUTOMATIC1111-mobile/extensions/sd-locon
# !mkdir /content/AUTOMATIC1111-mobile/models/ESRGAN
# !curl -Lo /content/AUTOMATIC1111-mobile/extensions/microsoftexcel-images-browser.zip https://github.com/noe999x/sd-$sysai/raw/main/microsoftexcel-images-browser.zip
# !curl -Lo /content/AUTOMATIC1111-mobile/embeddings/embeddings.zip https://github.com/noe999x/sd-$sysai/raw/main/embeddings.zip
# !curl -Lo /content/AUTOMATIC1111-mobile/models/ESRGAN/upscalers.zip https://huggingface.co/21sysai/upscalers/resolve/main/upscalers.zip
# %cd /content/AUTOMATIC1111-mobile/extensions
# !unzip /content/AUTOMATIC1111-mobile/extensions/microsoftexcel-images-browser.zip
# %cd /content/AUTOMATIC1111-mobile/embeddings
# !unzip /content/AUTOMATIC1111-mobile/embeddings/embeddings.zip
# %cd /content/AUTOMATIC1111-mobile/models/ESRGAN
# !unzip /content/AUTOMATIC1111-mobile/models/ESRGAN/upscalers.zip
clear_output()

###-deleted zip
print(f"{M}Menghapus file sampah...{D}")
#!rm /content/AUTOMATIC1111-mobile.rar
# !rm /content/AUTOMATIC1111-mobile/models/ESRGAN/upscalers.zip
# !rm /content/AUTOMATIC1111-mobile/embeddings/embeddings.zip
# !rm /content/AUTOMATIC1111-mobile/extensions/microsoftexcel-images-browser.zip
sleep(2)
# %cd /content
clear_output()

###-default model
print(f"{H}Menginstall Model Default...{D}")
# !curl -Lo /content/AUTOMATIC1111-mobile/models/Stable-diffusion/majicMIX_realisticv5.safetensors https://civitai.com/api/download/models/82446
# %cd /content
clear_output()

###-vae collection
print(f"{H}Menginstall VAE Collection[4.93GB]...{D}")
# !git clone --quiet https://huggingface.co/Kefasu/sd-vae-collection /content/AUTOMATIC1111-mobile/models/VAE
# %cd /content
clear_output()

print(f"{H}Instalasi selesai...", f"\n{B}Lanjutkan proses berikutnya.{D}")

# %%
#@markdown # Checkpoint
#@markdown  *Install Model / Checkpoint.*

ckpD = "/content/AUTOMATIC1111-mobile/models/Stable-diffusion"
vaeD = "/content/AUTOMATIC1111-mobile/models/VAE"

try:
    Model = "Default" #@param ["Default", "abyssorange_mix3", "anypastel", "dosmix", "meinahentai_v3", "perfectworld", "pikanewgeneration", "realdosmix", "toonyou"]
    WaI = f"{H}Menginstall model checkpoint...{D}"
    SuC = f"{D}Checkpoint {H}{Model} {D}berhasil terpasang!...{B}\nLanjutkan proses berikutnya.{D}"
    ErR = f"Kamu memilih {M}Default{D}\nTidak ada model terinstal.\n\n{H}majicmix_realistic5.safetensors{D}\nDigunakan sebagai model default.\n\n{B}Lanjutkan proses berikutnya.\n{D}Atau kamu bisa memilih kembali checkpoint yang akan di install."
    print(f"{WaI}")
    if Model == "Default":
       print(f"{ErR}")
    elif Model == "abyssorange_mix3":
       # !curl -Lo $ckpD/abyssorange3.safetensors https://tinyurl.com/abyssorng3
       # !curl -Lo $vaeD/abyssorange3.vae.pt https://tinyurl.com/21-abyssorng3
       clear_output()
       print(f"{SuC}")
    elif Model == "anypastel":
       # !curl -Lo $ckpD/nypastl.safetensors https://tinyurl.com/21sysai-anypastel
       # !curl -Lo $vaeD/nypastl.vae.pt https://tinyurl.com/21sysai-anypastel-vae
       clear_output()
       print(f"{SuC}")
    elif Model == "dosmix":
       # !curl -Lo $ckpD/dsmx.safetensors https://tinyurl.com/21sysai-dosmix
       # !curl -Lo $vaeD/dsmx.vae.pt https://tinyurl.com/21sysai-dosmix-vae
       clear_output()
       print(f"{SuC}")
    elif Model == "meinahentai_v3":
       # !curl -Lo $ckpD/meinahentv3.safetensors https://tinyurl.com/21sysai-mnh
       clear_output()
       print(f"{SuC}")
    elif Model == "perfectworld":
       # !curl -Lo $ckpD/perfectworld.safetensors https://tinyurl.com/21sysai-prfctwrld
       clear_output()
       print(f"{SuC}")
    elif Model == "pikanewgeneration":
       # !curl -Lo $ckpD/pikanewgen.safetensors https://tinyurl.com/21sysai-pikanewgen
       clear_output()
       print(f"{SuC}")
    elif Model == "realdosmix":
       # !curl -Lo $ckpD/rldsmx.safetensors https://tinyurl.com/rldsmx
       clear_output()
       print(f"{SuC}")
    elif Model == "toonyou":
       # !curl -Lo $ckpD/toonyou.safetensors https://tinyurl.com/21sysai-toonyou
       clear_output()
       print(f"{SuC}")
    else:print(f"{ErR}")
except:pass

# %%
#@markdown # ControlNet
#@markdown *Install Model ControlNet yang dibutuhkan.<br>Skip bagian jika tidak perlu.*
print(f"{H}Menginstall model ControlNet...{D}")
sleep(8)

Model = "None" #@param ["None", "Canny", "Depth", "Lineart", "MLSD", "Normal", "OpenPose", "Scribble", "Seg", "ip2p", "Shuffle", "Inpaint", "Softedge", "Lineart_Anime", "Tile"]

#pth
model_urls1 = {
    "Canny": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth',
    "Depth": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth',
    "Lineart": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart.pth',
    "MLSD": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd.pth',
    "Normal": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae.pth',
    "OpenPose": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth',
    "Scribble": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble.pth',
    "Seg": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg.pth',
    "ip2p": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p.pth',
    "Shuffle": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle.pth',
    "Inpaint": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth',
    "Softedge": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge.pth',
    "Lineart_Anime": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime.pth',
    "Tile": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile.pth'
}
#Safetensors
model_urls2 = {
    "Canny": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_canny_fp16.safetensors',
    "Depth": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_depth_fp16.safetensors',
    "Lineart": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_lineart_fp16.safetensors',
    "MLSD": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors',
    "Normal": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors',
    "OpenPose": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_openpose_fp16.safetensors',
    "Scribble": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_scribble_fp16.safetensors',
    "Seg": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_seg_fp16.safetensors',
    "ip2p": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors',
    "Shuffle": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors',
    "Inpaint": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors',
    "Softedge": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_softedge_fp16.safetensors',
    "Lineart_Anime": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors',
    "Tile": 'https://huggingface.co/nolanaatama/models/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors'
}

output_path = "/content/AUTOMATIC1111-mobile/models/ControlNet"

os.makedirs(output_path, exist_ok=True)  # Create the output directory if it doesn't exist

def download_model(model_url1, model_url2, output_path):
    filename = os.path.basename(model_url1)
    filename2 = os.path.basename(model_url2)
    output_file = os.path.join(output_path, filename)
    output_file2 = os.path.join(output_path, filename2)
    urllib.request.urlretrieve(model_url1, output_file)
    urllib.request.urlretrieve(model_url2, output_file2)
    return filename, filename2

if Model != "None":
    model_url1 = model_urls1.get(Model)
    model_url2 = model_urls2.get(Model)
    download_model(model_url1, model_url2, output_path)
    print(f"{D}Model {B}{Model} {D}berhasil terpasang!...{B}\nLanjutkan proses berikutnya.{D}")
else:
    #clear_output()
    print(f"{D}Anda memilih {M}None{D}\nTidak ada model terinstall...", f"{B}\nLanjutkan proses berikutnya,\n{D}Atau anda dapat memilih menginstall model kembali sebelum melanjutkan cell berikutnya.")

# %%
#@markdown #Install WEB-UI
#@markdown *Gunakan link <i>xxx.trycloudflare.com<i/>*

# %cd /content/AUTOMATIC1111-mobile/
clear_output()

print(f"{H}Menginstall interface web-ui...{D}")
sleep(2)

# Web UI tunnel
#!COMMANDLINE_ARGS="--share --disable-safe-unpickle --no-half-vae --xformers --enable-insecure-extension --gradio-queue" REQS_FILE="requirements.txt" python launch.py
# !COMMANDLINE_ARGS="--no-half-vae --share --allow-code --xformers --enable-insecure-extension --no-download --cloudflared" REQS_FILE="requirements.txt" python launch.py

# %% [markdown]
# <center>
#
# ---
#
# <font color="#CC3E3E" size="6"> <b><i>21sysai</b></i> </font>
#
# ---
#
# <p align="left"> <font ><b>Connect with me</b> :</font>
# <a href="https://instagram.com/bagaseka_apr" target="blank"><img align="center" src="https://raw.githubusercontent.com/rahuldkjain/github-profile-readme-generator/master/src/images/icons/Social/instagram.svg" alt="bagaseka_apr" height="30" width="40" /></a>
# <a href="https://fb.com/bagasekaaprs" target="blank"><img align="center" src="https://raw.githubusercontent.com/rahuldkjain/github-profile-readme-generator/master/src/images/icons/Social/facebook.svg" alt="noe999x" height="30" width="40" /></a>
# <a href="https://pinterest.com/21sysai/" target="blank"><img align="center" src="https://upload.wikimedia.org/wikipedia/commons/0/08/Pinterest-logo.png" alt="21sysai" height="30" width="30" /></a>
# <a href="https://pixiv.net/en/users/86925784" target="blank"><img align="center" src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Pixiv_Icon.svg/1200px-Pixiv_Icon.svg.png" alt="21sysai" height="30" width="30" /></a>
# <a href="https://github.com/noe999x" target="blank"><img align="center" src="https://cdn-icons-png.flaticon.com/512/25/25231.png" alt="noe999x" height="30" width="30" /></a></p>
#
# ---
#
# <p align="left"><font><b>Support me</b> :</font></p>
#
# <a href="https://www.buymeacoffee.com/21sysai"> <img align="center" src="https://cdn.buymeacoffee.com/buttons/v2/default-yellow.png" height="50" width="210" alt="21sysai" /></a><a href="https://trakteer.id/21sysai/tip"> <img align="center" src="https://trakteer.id/images/mix/navbar-logo-lite.png" height="50" width="210" alt="21sysai" /></a>
#
# ---
#
# <br><br><br><br>♥️
